# %%
import pandas as pd
import numpy as np
import scipy.stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import csv
  
# csv file name
filename = "car.csv"

# %%
path ='C:\Users\User\Project\car.csv'
# Out:
#   File "<ipython-input-17-8957fa65d78e>", line 1
#     path ='C:\Users\User\Project\car.csv'
#           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df = pd.read_csv('car.csv')

print(df)
# Out:
#            Brand                            Model     Accel  TopSpeed   Range  \
# 0         Tesla     Model 3 Long Range Dual Motor   4.6 sec  233 km/h  450 km
# 1    Volkswagen                         ID.3 Pure  10.0 sec  160 km/h  270 km
# 2      Polestar                                 2   4.7 sec  210 km/h  400 km
# 3           BMW                              iX3    6.8 sec  180 km/h  360 km
# 4         Honda                                e    9.5 sec  145 km/h  170 km
# ..           ...                              ...       ...       ...     ...
# 98       Nissan                       Ariya 63kWh   7.5 sec  160 km/h  330 km
# 99         Audi     e-tron S Sportback 55 quattro   4.5 sec  210 km/h  335 km
# 100      Nissan               Ariya e-4ORCE 63kWh   5.9 sec  200 km/h  325 km
# 101      Nissan   Ariya e-4ORCE 87kWh Performance   5.1 sec  200 km/h  375 km
# 102       Byton                 M-Byte 95 kWh 2WD   7.5 sec  190 km/h  400 km
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Brand        103 non-null    object
#  1   Model        103 non-null    object
#  2   Accel        103 non-null    object
#  3   TopSpeed     103 non-null    object
#  4   Range        103 non-null    object
#  5   Efficiency   103 non-null    object
#  6   FastCharge   103 non-null    object
#  7   RapidCharge  103 non-null    object
#  8   PowerTrain   103 non-null    object
#  9   PlugType     103 non-null    object
#  10  BodyStyle    103 non-null    object
#  11  Segment      103 non-null    object
#  12  Seats        103 non-null    int64
#  13  PriceEuro    103 non-null    int64
# dtypes: int64(2), object(12)
# memory usage: 11.4+ KB
# None

# %%
x = np.array(["Honda", "Tesla", "BMW", "Volkswagen", "Polestar"])
y = np.array([145, 233, 180, 160, 210,])

plt.bar(x, y, color = "orange")
plt.show()

print("\t\t\t Top 5 the fastest electric cars")
# Out:
# 			 Top 5 the fastest electric cars

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["45  SUV",
          "5  Liftback",
          "10  Sedan",
          "32  Hatchback"]

data = [float(x.split()[0]) for x in recipe]
BodysStyle = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:.1f}\n({:d} %)".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, BodysStyle,
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Electric cars Body style: A pie")

plt.show()

# %%
plt.title('Top 6 Expensive electric cars')
plt.bar(x,y,width=0.6, color=c)
x=["Audi","Porsche","Lightyear ","Tesla","Jaguar.","Lucid"]
y=[125000,180781,149000,215000,80000,105000]
c=["grey","grey","grey","grey","grey","grey"]
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
year = [100, 200, 300, 400, 500, 600, 700, 800]
population_by_continent = {
    'Tesla': [100, 100, 365, 477, 631, 814, 1044, 100],
    'Lucid': [100, 425, 519, 619, 727, 840, 943, 106],
    'Lightyear': [100, 1687, 2127, 2629, 3204, 3717, 4161, 145],
    'BMW': [100, 253, 276, 295, 310, 303, 294, 293],
    'Ford': [100, 1500, 1900, 2200, 2600, 3100, 3600, 150],
}
fig, ax = plt.subplots()
ax.stackplot(year, population_by_continent.values(),
             labels=population_by_continent.keys())

ax.legend(loc='upper left')
ax.set_title('Electric cars range comparison')
ax.set_xlabel('Range')


plt.show()

# %%
import numpy
from matplotlib import pyplot as plt

plt.title("Electric cars range comparison")

subjects = ['Mercedes', 'Nissan', 'chem', 'BMW', 'Honda',
            'Ford', 'Volvo', 'Hyundai', 'Lexus', 'Citroen',
            'Nissan', 'Tesla', 'Lightyear', 'Lucid', 'Renault',
            ]


x=[400,600,490,215,900,205]


# Plotting
plt.barh(subjects, marks, ) 

plt.xlabel("Range")
plt.ylabel("Brands")



plt.savefig("plot.png")
plt.show()
